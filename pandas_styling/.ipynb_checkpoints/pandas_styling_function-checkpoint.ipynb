# %% [markdown]
# ### 👉 Import required libraries

# %%
import pandas as pd

# %% [markdown]
# ### 👉 define dataframe

# %%
df = pd.read_csv(r"./datasets/accident-data.csv")

# %%
df.head().style.highlight_max()
# Out:
# <style type="text/css">
# #T_c6b9b_row0_col1, #T_c6b9b_row0_col5, #T_c6b9b_row0_col6, #T_c6b9b_row0_col11, #T_c6b9b_row0_col13, #T_c6b9b_row0_col17, #T_c6b9b_row0_col18, #T_c6b9b_row0_col19, #T_c6b9b_row0_col20, #T_c6b9b_row0_col22, #T_c6b9b_row0_col23, #T_c6b9b_row0_col24, #T_c6b9b_row0_col25, #T_c6b9b_row0_col26, #T_c6b9b_row1_col1, #T_c6b9b_row1_col5, #T_c6b9b_row1_col6, #T_c6b9b_row1_col7, #T_c6b9b_row1_col8, #T_c6b9b_row1_col10, #T_c6b9b_row1_col12, #T_c6b9b_row1_col13, #T_c6b9b_row1_col15, #T_c6b9b_row1_col17, #T_c6b9b_row1_col18, #T_c6b9b_row1_col24, #T_c6b9b_row1_col25, #T_c6b9b_row1_col26, #T_c6b9b_row2_col1, #T_c6b9b_row2_col5, #T_c6b9b_row2_col6, #T_c6b9b_row2_col9, #T_c6b9b_row2_col13, #T_c6b9b_row2_col14, #T_c6b9b_row2_col17, #T_c6b9b_row2_col18, #T_c6b9b_row2_col21, #T_c6b9b_row2_col24, #T_c6b9b_row2_col25, #T_c6b9b_row2_col26, #T_c6b9b_row3_col1, #T_c6b9b_row3_col3, #T_c6b9b_row3_col4, #T_c6b9b_row3_col6, #T_c6b9b_row3_col9, #T_c6b9b_row3_col13, #T_c6b9b_row3_col14, #T_c6b9b_row3_col17, #T_c6b9b_row3_col18, #T_c6b9b_row3_col21, #T_c6b9b_row3_col24, #T_c6b9b_row3_col25, #T_c6b9b_row3_col26, #T_c6b9b_row4_col0, #T_c6b9b_row4_col1, #T_c6b9b_row4_col2, #T_c6b9b_row4_col5, #T_c6b9b_row4_col6, #T_c6b9b_row4_col7, #T_c6b9b_row4_col9, #T_c6b9b_row4_col13, #T_c6b9b_row4_col14, #T_c6b9b_row4_col16, #T_c6b9b_row4_col18, #T_c6b9b_row4_col21, #T_c6b9b_row4_col24, #T_c6b9b_row4_col25, #T_c6b9b_row4_col26 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c6b9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6b9b_level0_col0" class="col_heading level0 col0" >accident_index</th>
#       <th id="T_c6b9b_level0_col1" class="col_heading level0 col1" >accident_year</th>
#       <th id="T_c6b9b_level0_col2" class="col_heading level0 col2" >accident_reference</th>
#       <th id="T_c6b9b_level0_col3" class="col_heading level0 col3" >longitude</th>
#       <th id="T_c6b9b_level0_col4" class="col_heading level0 col4" >latitude</th>
#       <th id="T_c6b9b_level0_col5" class="col_heading level0 col5" >accident_severity</th>
#       <th id="T_c6b9b_level0_col6" class="col_heading level0 col6" >number_of_vehicles</th>
#       <th id="T_c6b9b_level0_col7" class="col_heading level0 col7" >number_of_casualties</th>
#       <th id="T_c6b9b_level0_col8" class="col_heading level0 col8" >date</th>
#       <th id="T_c6b9b_level0_col9" class="col_heading level0 col9" >day_of_week</th>
#       <th id="T_c6b9b_level0_col10" class="col_heading level0 col10" >time</th>
#       <th id="T_c6b9b_level0_col11" class="col_heading level0 col11" >first_road_class</th>
#       <th id="T_c6b9b_level0_col12" class="col_heading level0 col12" >first_road_number</th>
#       <th id="T_c6b9b_level0_col13" class="col_heading level0 col13" >road_type</th>
#       <th id="T_c6b9b_level0_col14" class="col_heading level0 col14" >speed_limit</th>
#       <th id="T_c6b9b_level0_col15" class="col_heading level0 col15" >junction_detail</th>
#       <th id="T_c6b9b_level0_col16" class="col_heading level0 col16" >junction_control</th>
#       <th id="T_c6b9b_level0_col17" class="col_heading level0 col17" >second_road_class</th>
#       <th id="T_c6b9b_level0_col18" class="col_heading level0 col18" >second_road_number</th>
#       <th id="T_c6b9b_level0_col19" class="col_heading level0 col19" >pedestrian_crossing_human_control</th>
#       <th id="T_c6b9b_level0_col20" class="col_heading level0 col20" >pedestrian_crossing_physical_facilities</th>
#       <th id="T_c6b9b_level0_col21" class="col_heading level0 col21" >light_conditions</th>
#       <th id="T_c6b9b_level0_col22" class="col_heading level0 col22" >weather_conditions</th>
#       <th id="T_c6b9b_level0_col23" class="col_heading level0 col23" >road_surface_conditions</th>
#       <th id="T_c6b9b_level0_col24" class="col_heading level0 col24" >special_conditions_at_site</th>
#       <th id="T_c6b9b_level0_col25" class="col_heading level0 col25" >carriageway_hazards</th>
#       <th id="T_c6b9b_level0_col26" class="col_heading level0 col26" >urban_or_rural_area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6b9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6b9b_row0_col0" class="data row0 col0" >2020010219808</td>
#       <td id="T_c6b9b_row0_col1" class="data row0 col1" >2020</td>
#       <td id="T_c6b9b_row0_col2" class="data row0 col2" >10219808</td>
#       <td id="T_c6b9b_row0_col3" class="data row0 col3" >-0.254001</td>
#       <td id="T_c6b9b_row0_col4" class="data row0 col4" >51.462262</td>
#       <td id="T_c6b9b_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_c6b9b_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_c6b9b_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_c6b9b_row0_col8" class="data row0 col8" >04/02/2020</td>
#       <td id="T_c6b9b_row0_col9" class="data row0 col9" >3</td>
#       <td id="T_c6b9b_row0_col10" class="data row0 col10" >09:00</td>
#       <td id="T_c6b9b_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_c6b9b_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_c6b9b_row0_col13" class="data row0 col13" >6</td>
#       <td id="T_c6b9b_row0_col14" class="data row0 col14" >20</td>
#       <td id="T_c6b9b_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_c6b9b_row0_col16" class="data row0 col16" >-1</td>
#       <td id="T_c6b9b_row0_col17" class="data row0 col17" >6</td>
#       <td id="T_c6b9b_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_c6b9b_row0_col19" class="data row0 col19" >9</td>
#       <td id="T_c6b9b_row0_col20" class="data row0 col20" >9</td>
#       <td id="T_c6b9b_row0_col21" class="data row0 col21" >1</td>
#       <td id="T_c6b9b_row0_col22" class="data row0 col22" >9</td>
#       <td id="T_c6b9b_row0_col23" class="data row0 col23" >9</td>
#       <td id="T_c6b9b_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_c6b9b_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_c6b9b_row0_col26" class="data row0 col26" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c6b9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6b9b_row1_col0" class="data row1 col0" >2020010220496</td>
#       <td id="T_c6b9b_row1_col1" class="data row1 col1" >2020</td>
#       <td id="T_c6b9b_row1_col2" class="data row1 col2" >10220496</td>
#       <td id="T_c6b9b_row1_col3" class="data row1 col3" >-0.139253</td>
#       <td id="T_c6b9b_row1_col4" class="data row1 col4" >51.470327</td>
#       <td id="T_c6b9b_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_c6b9b_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_c6b9b_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_c6b9b_row1_col8" class="data row1 col8" >27/04/2020</td>
#       <td id="T_c6b9b_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_c6b9b_row1_col10" class="data row1 col10" >13:55</td>
#       <td id="T_c6b9b_row1_col11" class="data row1 col11" >3</td>
#       <td id="T_c6b9b_row1_col12" class="data row1 col12" >3036</td>
#       <td id="T_c6b9b_row1_col13" class="data row1 col13" >6</td>
#       <td id="T_c6b9b_row1_col14" class="data row1 col14" >20</td>
#       <td id="T_c6b9b_row1_col15" class="data row1 col15" >9</td>
#       <td id="T_c6b9b_row1_col16" class="data row1 col16" >2</td>
#       <td id="T_c6b9b_row1_col17" class="data row1 col17" >6</td>
#       <td id="T_c6b9b_row1_col18" class="data row1 col18" >0</td>
#       <td id="T_c6b9b_row1_col19" class="data row1 col19" >0</td>
#       <td id="T_c6b9b_row1_col20" class="data row1 col20" >4</td>
#       <td id="T_c6b9b_row1_col21" class="data row1 col21" >1</td>
#       <td id="T_c6b9b_row1_col22" class="data row1 col22" >1</td>
#       <td id="T_c6b9b_row1_col23" class="data row1 col23" >1</td>
#       <td id="T_c6b9b_row1_col24" class="data row1 col24" >0</td>
#       <td id="T_c6b9b_row1_col25" class="data row1 col25" >0</td>
#       <td id="T_c6b9b_row1_col26" class="data row1 col26" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c6b9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6b9b_row2_col0"

# %%
def pandas_styling(df):
     return df.style.highlight_max().highlight_min().highlight_null(null_color = 'blue')

# %%
pandas_styling(df.isna(subset = [['latitude', 'longitude']]).head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 pandas_styling(df.isna(subset = [['latitude', 'longitude']]).head())
#
# TypeError: isna() got an unexpected keyword argument 'subset'

# %%
df[df[['latitude', 'longitude']].isna() == False]
# Out:
#       accident_index  accident_year accident_reference  longitude   latitude  \
# 0                NaN            NaN                NaN  -0.254001  51.462262
# 1                NaN            NaN                NaN  -0.139253  51.470327
# 2                NaN            NaN                NaN  -0.178719  51.529614
# 3                NaN            NaN                NaN  -0.001683  51.541210
# 4                NaN            NaN                NaN  -0.137592  51.515704
# ...              ...            ...                ...        ...        ...
# 91194            NaN            NaN                NaN  -2.926320  56.473539
# 91195            NaN            NaN                NaN  -4.267565  55.802353
# 91196            NaN            NaN                NaN  -2.271903  57.186317
# 91197            NaN            NaN                NaN  -3.968753  55.950940
# 91198            NaN            NaN                NaN  -4.561040  56.003843
#
#        accident_severity  number_of_vehicles  number_of_casualties date  \
# 0                    NaN                 NaN                   NaN  NaN
# 1                    NaN                 NaN                   NaN  NaN
# 2                    NaN                 NaN                   NaN  NaN
# 3                    NaN                 NaN                   NaN  NaN
# 4                    NaN                 NaN                   NaN  NaN
# ...                  ...                 ...                   ...  ...
# 91194                NaN                 NaN                   NaN  NaN
# 91195                NaN                 NaN                   NaN  NaN
# 91196                NaN                 NaN                   NaN  NaN
# 91197                NaN                 NaN                   NaN  NaN
# 91198                NaN                 NaN                   NaN  NaN
#
#        day_of_week  ... second_road_class  second_road_number  \
# 0              NaN  ...               NaN                 NaN
# 1              NaN  ...               NaN                 NaN
# 2              NaN  ...               NaN                 NaN
# 3              NaN  ...               NaN                 NaN
# 4              NaN  ...               NaN                 NaN
# ...            ...  ...               ...                 ...
# 91194          NaN  ...               NaN                 NaN
# 91195          NaN  ...               NaN                 NaN
# 91196          NaN  ...               NaN                 NaN
# 91197          NaN  ...               NaN                 NaN
# 91198          NaN  ...               NaN                 NaN
#
#        pedestrian_crossing_human_control  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 91194                                NaN
# 91195                                NaN
# 91196                                NaN
# 91197                                NaN
# 91198                                NaN
#
#        pedestrian_crossing_physical_facilities  light_conditions  \
# 0                                          NaN               NaN
# 1                                          NaN               NaN
# 2                                          NaN               NaN
# 3                                          NaN               NaN
# 4                                          NaN               NaN
# ...                                        ...               ...
# 91194                                      NaN               NaN
# 91195                                      NaN               NaN
# 91196                                      NaN               NaN
# 91197                                      NaN               NaN
# 91198                                      NaN               NaN
#
#        weather_conditions  road_surface_conditions  \
# 0                     NaN                      NaN
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
# ...                   ...                      ...
# 91194                 NaN                      NaN
# 91195                 NaN                      NaN
# 91196                 NaN                      NaN
# 91197                 NaN                      NaN
# 91198                 NaN                      NaN
#
#        special_conditions_at_site  carriageway_hazards  urban_or_rural_area
# 0                             NaN                  NaN                  NaN
# 1                             NaN                  NaN                  NaN
# 2                             NaN                  NaN                  NaN
# 3                             NaN                  NaN                  NaN
# 4                             NaN                  NaN                  NaN
# ...                           ...                  ...                  ...
# 91194                         NaN                  NaN                  NaN
# 91195                         NaN                  NaN                  NaN
# 91196                         NaN                  NaN                  NaN
# 91197                         NaN                  NaN                  NaN
# 91198                         NaN                  NaN                  NaN
#
# [91199 rows x 27 columns]

# %%
cols = ['latitude', 'longitude']
pandas_styling(df[df['latitude'].isna()])
# Out:
# <style type="text/css">
# #T_df78d_row0_col0, #T_df78d_row0_col2, #T_df78d_row0_col5, #T_df78d_row0_col7, #T_df78d_row0_col17, #T_df78d_row0_col18, #T_df78d_row0_col20, #T_df78d_row0_col21, #T_df78d_row0_col22, #T_df78d_row1_col5, #T_df78d_row1_col7, #T_df78d_row1_col9, #T_df78d_row1_col12, #T_df78d_row1_col17, #T_df78d_row1_col18, #T_df78d_row1_col20, #T_df78d_row1_col21, #T_df78d_row1_col22, #T_df78d_row2_col5, #T_df78d_row2_col7, #T_df78d_row2_col8, #T_df78d_row2_col11, #T_df78d_row2_col12, #T_df78d_row2_col13, #T_df78d_row2_col14, #T_df78d_row2_col16, #T_df78d_row2_col17, #T_df78d_row2_col18, #T_df78d_row2_col20, #T_df78d_row2_col21, #T_df78d_row2_col23, #T_df78d_row3_col5, #T_df78d_row3_col7, #T_df78d_row3_col8, #T_df78d_row3_col11, #T_df78d_row3_col16, #T_df78d_row3_col17, #T_df78d_row3_col20, #T_df78d_row3_col21, #T_df78d_row3_col22, #T_df78d_row4_col5, #T_df78d_row4_col6, #T_df78d_row4_col7, #T_df78d_row4_col13, #T_df78d_row4_col16, #T_df78d_row4_col17, #T_df78d_row4_col20, #T_df78d_row4_col21, #T_df78d_row4_col22, #T_df78d_row5_col5, #T_df78d_row5_col7, #T_df78d_row5_col11, #T_df78d_row5_col12, #T_df78d_row5_col14, #T_df78d_row5_col15, #T_df78d_row5_col17, #T_df78d_row5_col18, #T_df78d_row5_col20, #T_df78d_row5_col22, #T_df78d_row6_col5, #T_df78d_row6_col7, #T_df78d_row6_col15, #T_df78d_row6_col16, #T_df78d_row6_col17, #T_df78d_row6_col18, #T_df78d_row6_col20, #T_df78d_row6_col21, #T_df78d_row6_col22, #T_df78d_row6_col23, #T_df78d_row7_col5, #T_df78d_row7_col7, #T_df78d_row7_col10, #T_df78d_row7_col16, #T_df78d_row7_col17, #T_df78d_row7_col18, #T_df78d_row7_col20, #T_df78d_row7_col21, #T_df78d_row7_col22, #T_df78d_row8_col5, #T_df78d_row8_col7, #T_df78d_row8_col15, #T_df78d_row8_col16, #T_df78d_row8_col17, #T_df78d_row8_col18, #T_df78d_row8_col20, #T_df78d_row8_col21, #T_df78d_row8_col23, #T_df78d_row9_col5, #T_df78d_row9_col6, #T_df78d_row9_col7, #T_df78d_row9_col11, #T_df78d_row9_col12, #T_df78d_row9_col14, #T_df78d_row9_col15, #T_df78d_row9_col16, #T_df78d_row9_col17, #T_df78d_row9_col18, #T_df78d_row9_col20, #T_df78d_row9_col21, #T_df78d_row9_col22, #T_df78d_row10_col5, #T_df78d_row10_col7, #T_df78d_row10_col14, #T_df78d_row10_col15, #T_df78d_row10_col16, #T_df78d_row10_col17, #T_df78d_row10_col18, #T_df78d_row10_col20, #T_df78d_row10_col21, #T_df78d_row10_col22, #T_df78d_row11_col5, #T_df78d_row11_col7, #T_df78d_row11_col11, #T_df78d_row11_col12, #T_df78d_row11_col16, #T_df78d_row11_col17, #T_df78d_row11_col18, #T_df78d_row11_col20, #T_df78d_row11_col21, #T_df78d_row11_col22, #T_df78d_row12_col5, #T_df78d_row12_col7, #T_df78d_row12_col9, #T_df78d_row12_col11, #T_df78d_row12_col12, #T_df78d_row12_col14, #T_df78d_row12_col15, #T_df78d_row12_col16, #T_df78d_row12_col17, #T_df78d_row12_col18, #T_df78d_row12_col20, #T_df78d_row12_col21, #T_df78d_row12_col22, #T_df78d_row13_col0, #T_df78d_row13_col2, #T_df78d_row13_col5, #T_df78d_row13_col6, #T_df78d_row13_col7, #T_df78d_row13_col9, #T_df78d_row13_col10, #T_df78d_row13_col14, #T_df78d_row13_col15, #T_df78d_row13_col16, #T_df78d_row13_col17, #T_df78d_row13_col18, #T_df78d_row13_col20 {
#   background-color: yellow;
# }
# #T_df78d_row0_col1, #T_df78d_row0_col19, #T_df78d_row0_col24, #T_df78d_row0_col25, #T_df78d_row0_col26, #T_df78d_row1_col1, #T_df78d_row1_col19, #T_df78d_row1_col24, #T_df78d_row1_col25, #T_df78d_row1_col26, #T_df78d_row2_col1, #T_df78d_row2_col19, #T_df78d_row2_col24, #T_df78d_row2_col25, #T_df78d_row2_col26, #T_df78d_row3_col1, #T_df78d_row3_col19, #T_df78d_row3_col24, #T_df78d_row3_col25, #T_df78d_row3_col26, #T_df78d_row4_col1, #T_df78d_row4_col19, #T_df78d_row4_col24, #T_df78d_row4_col25, #T_df78d_row4_col26, #T_df78d_row5_col1, #T_df78d_row5_col19, #T_df78d_row5_col24, #T_df78d_row5_col25, #T_df78d_row5_col26, #T_df78d_row6_col1, #T_df78d_row6_col19, #T_df78d_row6_col24, #T_df78d_row6_col25, #T_df78d_row6_col26, #T_df78d_row7_col1, #T_df78d_row7_col19, #T_df78d_row7_col24, #T_df78d_row7_col25, #T_df78d_row7_col26, #T_df78d_row8_col1, #T_df78d_row8_col19, #T_df78d_row8_col24, #T_df78d_row8_col25, #T_df78d_row8_col26, #T_df78d_row9_col1, #T_df78d_row9_col19, #T_df78d_row9_col24, #T_df78d_row9_col25, #T_df78d_row9_col26, #T_df78d_row10_col1, #T_df78d_row10_col19, #T_df78d_row10_col24, #T_df78d_row10_col25, #T_df78d_row10_col26, #T_df78d_row11_col1, #T_df78d_row11_col19, #T_df78d_row11_col24, #T_df78d_row11_col25, #T_df78d_row11_col26, #T_df78d_row12_col1, #T_df78d_row12_col19, #T_df78d_row12_col24, #T_df78d_row12_col25, #T_df78d_row12_col26, #T_df78d_row13_col1, #T_df78d_row13_col19, #T_df78d_row13_col24, #T_df78d_row13_col25, #T_df78d_row13_col26 {
#   background-color: yellow;
#   background-color: yellow;
# }
# #T_df78d_row0_col3, #T_df78d_row0_col4, #T_df78d_row1_col3, #T_df78d_row1_col4, #T_df78d_row2_col3, #T_df78d_row2_col4, #T_df78d_row3_col3, #T_df78d_row3_col4, #T_df78d_row4_col3, #T_df78d_row4_col4, #T_df78d_row5_col3, #T_df78d_row5_col4, #T_df78d_row6_col3, #T_df78d_row6_col4, #T_df78d_row7_col3, #T_df78d_row7_col4, #T_df78d_row8_col3, #T_df78d_row8_col4, #T_df78d_row9_col3, #T_df78d_row9_col4, #T_df78d_row10_col3, #T_df78d_row10_col4, #T_df78d_row11_col3, #T_df78d_row11_col4, #T_df78d_row12_col3, #T_df78d_row12_col4, #T_df78d_row13_col3, #T_df78d_row13_col4 {
#   background-color: blue;
# }
# </style>
# <table id="T_df78d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df78d_level0_col0" class="col_heading level0 col0" >accident_index</th>
#       <th id="T_df78d_level0_col1" class="col_heading level0 col1" >accident_year</th>
#       <th id="T_df78d_level0_col2" class="col_heading level0 col2" >accident_reference</th>
#       <th id="T_df78d_level0_col3" class="col_heading level0 col3" >longitude</th>
#       <th id="T_df78d_level0_col4" class="col_heading level0 col4" >latitude</th>
#       <th id="T_df78d_level0_col5" class="col_heading level0 col5" >accident_severity</th>
#       <th id="T_df78d_level0_col6" class="col_heading level0 col6" >number_of_vehicles</th>
#       <th id="T_df78d_level0_col7" class="col_heading level0 col7" >number_of_casualties</th>
#       <th id="T_df78d_level0_col8" class="col_heading level0 col8" >date</th>
#       <th id="T_df78d_level0_col9" class="col_heading level0 col9" >day_of_week</th>
#       <th id="T_df78d_level0_col10" class="col_heading level0 col10" >time</th>
#       <th id="T_df78d_level0_col11" class="col_heading level0 col11" >first_road_class</th>
#       <th id="T_df78d_level0_col12" class="col_heading level0 col12" >first_road_number</th>
#       <th id="T_df78d_level0_col13" class="col_heading level0 col13" >road_type</th>
#       <th id="T_df78d_level0_col14" class="col_heading level0 col14" >speed_limit</th>
#       <th id="T_df78d_level0_col15" class="col_heading level0 col15" >junction_detail</th>
#       <th id="T_df78d_level0_col16" class="col_heading level0 col16" >junction_control</th>
#       <th id="T_df78d_level0_col17" class="col_heading level0 col17" >second_road_class</th>
#       <th id="T_df78d_level0_col18" class="col_heading level0 col18" >second_road_number</th>
#       <th id="T_df78d_level0_col19" class="col_heading level0 col19" >pedestrian_crossing_human_control</th>
#       <th id="T_df78d_level0_col20" class="col_heading level0 col20" >pedestrian_crossing_physical_facilities</th>
#       <th id="T_df78d_level0_col21" class="col_heading level0 col21" >light_conditions</th>
#       <th id="T_df78d_level0_col22" class="col_heading level0 col22" >weather_conditions</th>
#       <th id="T_df78d_level0_col23" class="col_heading level0 col23" >road_surface_conditions</th>
#       <th id="T_df78d_level0_col24" class="col_heading level0 col24" >special_conditions_at_site</th>
#       <th id="T_df78d_level0_col25" class="col_heading level0 col25" >carriageway_hazards</th>
#       <th id="T_df78d_level0_col26" class="col_heading level0 col26" >urban_or_rural_area</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df78d_level0_row0" class="row_heading level0 row0" >25520</th>
#       <td id="T_df78d_row0_col0" class="data row0
