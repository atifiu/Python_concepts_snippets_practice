# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv('./dataset/FIFA.csv')
df.shape
# Out:
# CPU times: total: 3.66 s
# Wall time: 4.25 s
# (530000, 16)

# %%
# %%time
i = 0
with pd.read_csv('./dataset/FIFA.csv', chunksize = 100000) as reader:
    df = pd.concat(reader, ignore_index = False)
# Out:
# <class 'pandas.io.parsers.readers.TextFileReader'>
# 1
# CPU times: total: 3.53 s
# Wall time: 3.72 s

# %%
# %%time
df = pd.concat([chunk for chunk in pd.read_csv('./dataset/FIFA.csv', chunksize = 100000)])
# Out:
# CPU times: total: 4.06 s
# Wall time: 4.57 s

# %%
df.tail()
# Out:
#                          ID lang                 Date               Source  \
# 529995  1018628575782580224   en  2018-07-15 22:49:12  Twitter for Android
# 529996  1018628575531061249   en  2018-07-15 22:49:12   Twitter for iPhone
# 529997  1018628575023521793   en  2018-07-15 22:49:12   Twitter Web Client
# 529998  1018628574729949184   en  2018-07-15 22:49:12  Twitter for Android
# 529999  1018628574272786438   en  2018-07-15 22:49:11   Twitter Web Client
#
#         len                                         Orig_Tweet  \
# 529995  131  RT @FIFAWorldCup: ????\r\n#FRA\r\n\r\nFrance h...
# 529996  144  RT @BeyLegion: Beyoncé &amp; JAY-Z performed i...
# 529997  140  RT @KhaledBeydoun: They don’t say “immigrants ...
# 529998   93  RT @ManUtd: .@PaulPogba starts for #FRA in tod...
# 529999  140  RT @KhaledBeydoun: Dear France, \r\n\r\nCongra...
#
#                                                     Tweet  Likes    RTs  \
# ...

# %%
# %%time
list1 = []
for chunk in pd.read_csv('./dataset/FIFA.csv', chunksize = 100000):
    list1.append(chunk)
pd.concat(list1, axis = 0)
# Out:
# CPU times: total: 4.09 s
# Wall time: 4.44 s
#                          ID lang                 Date               Source  \
# 0       1013597060640145408   en  2018-07-02 01:35:45  Twitter for Android
# 1       1013597056219295744   en  2018-07-02 01:35:44  Twitter for Android
# 2       1013597047482544130   en  2018-07-02 01:35:42  Twitter for Android
# 3       1013597044198391808   en  2018-07-02 01:35:41   Twitter Web Client
# 4       1013597039999926272   en  2018-07-02 01:35:40  Twitter for Android
# ...                     ...  ...                  ...                  ...
# 529995  1018628575782580224   en  2018-07-15 22:49:12  Twitter for Android
# 529996  1018628575531061249   en  2018-07-15 22:49:12   Twitter for iPhone
# 529997  1018628575023521793   en  2018-07-15 22:49:12   Twitter Web Client
# 529998  1018628574729949184   en  2018-07-15 22:49:12  Twitter for Android
# 529999  1018628574272786438   en  2018-07-15 22:49:11   Twitter Web Client
#
# ...
